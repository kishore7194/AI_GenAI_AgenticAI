# %%
1
# Out:
# 1

# %%
10 + 11
# Out:
# 21

# %%
2 + 3 - (1*2)
# Out:
# 3

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4])

# %%
plt.plot([1, 4, 9, 16])

# %%
plt.plot([1, 8, 27, 64])

# %%
10
# Out:
# 10

# %%
_ + 2
# Out:
# 12
